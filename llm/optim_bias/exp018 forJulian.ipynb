# %% [markdown]
# Fit models (for different test rewards)

# %%
import argparse
import os
import sys
import glob

import numpy as np
import pandas as pd

from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

sys.path.append('../src/')
#from rw_fitting import predict_exp

# %%
csv_file = '/eris/scratch/jschubert/training/high_low/RL__rc_0.85__efv_0w__rew_0__id_0/simulation_df.csv'
model_names = csv_file.split('/')[-2]
model_namesenv_mode_name = ['high']
df_sim = pd.read_csv(csv_file)
df_sim['prob'] = env_mode_name[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /u/jschubert/learning_bias/llm/optim_bias/exp018 forJulian.ipynb Cell 3 line 4
#       <a href='vscode-notebook-cell://ssh-remote%2Beris01.bc.rzg.mpg.de/u/jschubert/learning_bias/llm/optim_bias/exp018%20forJulian.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> model_names = csv_file.split('/')[-2]
#       <a href='vscode-notebook-cell://ssh-remote%2Beris01.bc.rzg.mpg.de/u/jschubert/learning_bias/llm/optim_bias/exp018%20forJulian.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> model_namesenv_mode_name = ['high']
# ----> <a href='vscode-notebook-cell://ssh-remote%2Beris01.bc.rzg.mpg.de/u/jschubert/learning_bias/llm/optim_bias/exp018%20forJulian.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> df_sim = pd.read_csv(csv_file)
# ...

# %% [markdown]
# set initial q values for Rescorla-Wagner model

# %%
q_initals = np.asarray([[0.25,0.25],[0.25,0.25],[0.25,0.25],[0.25,0.25]])

# %%
random_alpha_range = (0,1) # samples uniformly in between this range as an inital guess for alpha
random_beta_range = (0,5) # and for beta respectively.
optim_bounds = ([0,1],[0, np.inf]) #alpha, beta | bounds during optimization
n_optim_inits = 10 # how often the optimization procedure is repeated


actions = df_sim.pivot(index='test_part_idx',columns='trials_idx',values='actions').values.astype(int)
rewards = df_sim.pivot(index='test_part_idx',columns='trials_idx',values='rewards').values
cues = df_sim.pivot(index='test_part_idx',columns='trials_idx',values='cues').values.astype(int)

pipeline = predict_exp(random_alpha_range, random_beta_range, q_initals, n_optim_inits, optim_bounds, concatenated_trial=False)        
df = pipeline.fit(actions,rewards,cues,bounded=True)
df['prob'] = env_mode_name[i]
df['bic_dif'] = df['c_bic'] - df['pm_bic']
df['is_pm'] = df['bic_dif'] >= 0
df['c_1/b'] = 1 / df['c_b']
df['pm_1/b'] = 1 / df['pm_b']
df['model_path'] = model_names[i]
path = base_path + model_names[i]
#df.to_csv(path+"/rw_fit_high_low.csv", index=False, mode='w')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_75313/4069346707.py in <module>
#      10
#      11 pipeline = predict_exp(random_alpha_range, random_beta_range, q_initals, n_optim_inits, optim_bounds, concatenated_trial=False)
# ---> 12 df = pipeline.fit(actions,rewards,cues,bounded=True)
#      13 df['prob'] = env_mode_name[i]
#      14 df['bic_dif'] = df['c_bic'] - df['pm_bic']
#
# /eris/u/jschubert/optimbias/rw_model/exp_jupyter/../src/rw_fitting.py in fit(self, choices, rewards, contexts, bounded)
#      45             context = contexts[p,:]
#      46
# ---> 47             c_nll, c_a, c_b = self.c_fit(c, r, context, bounded)
#      48             pm_nll, p_a, m_a, pm_b = self.pm_fit(c, r, context, bounded)
#      49
#
# /eris/u/jschubert/optimbias/rw_model/exp_jupyter/../src/rw_fitting.py in c_fit(self, c, r, context, bounds)
# ...
